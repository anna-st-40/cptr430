# %%
class EightPuzzle:
    """Represents an 8-puzzle problem."""
    
    def __init__(self, initial_state, goal_state):
        self.initial = initial_state
        self.goal = goal_state
    
    def get_actions(self, state):
        """Returns list of valid actions from this state."""
        actions = []
        blank_pos = state.index(0)  # Find the blank tile
        row, col = blank_pos // 3, blank_pos % 3
        
        if row > 0: actions.append('UP')
        if row < 2: actions.append('DOWN')
        if col > 0: actions.append('LEFT')
        if col < 2: actions.append('RIGHT')
        
        return actions
    
    def result(self, state, action):
        """Returns the state that results from executing action."""
        new_state = list(state)
        blank_pos = state.index(0)
        row, col = blank_pos // 3, blank_pos % 3
        
        # Calculate new position based on action
        if action == 'UP':
            new_pos = (row - 1) * 3 + col
        elif action == 'DOWN':
            new_pos = (row + 1) * 3 + col
        elif action == 'LEFT':
            new_pos = row * 3 + (col - 1)
        elif action == 'RIGHT':
            new_pos = row * 3 + (col + 1)
        
        # Swap blank with tile in new position
        new_state[blank_pos], new_state[new_pos] = new_state[new_pos], new_state[blank_pos]
        return tuple(new_state)
    
    def is_goal(self, state):
        """Tests if state is the goal."""
        return state == self.goal
    
    def display_state(self, state):
        """Pretty print a state."""
        for i in range(0, 9, 3):
            print(f"  {state[i]} {state[i+1]} {state[i+2]}")

# Create a problem instance
initial = (1, 2, 3, 4, 0, 5, 6, 7, 8)  # 0 represents blank
goal = (0, 1, 2, 3, 4, 5, 6, 7, 8)

problem = EightPuzzle(initial, goal)

print("PROBLEM FORMULATION DEMONSTRATION")
print("=" * 50)
print("\nInitial State:")
problem.display_state(initial)

print("\nGoal State:")
problem.display_state(goal)

print("\nAvailable actions from initial state:", problem.get_actions(initial))

print("\nApplying action 'UP':")
new_state = problem.result(initial, 'UP')
problem.display_state(new_state)

print("\nIs new state the goal?", problem.is_goal(new_state))
print("Is goal state the goal?", problem.is_goal(goal))

print("\nPath cost: Each move costs 1 (implicit in our formulation)")
# Out:
# PROBLEM FORMULATION DEMONSTRATION
# ==================================================
#
# Initial State:
#   1 2 3
#   4 0 5
#   6 7 8
#
# Goal State:
#   0 1 2
#   3 4 5
#   6 7 8
#
# Available actions from initial state: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#
# Applying action 'UP':
#   1 0 3
#   4 2 5
#   6 7 8
#
# Is new state the goal? False
# Is goal state the goal? True
#
# Path cost: Each move costs 1 (implicit in our formulation)

# %%
from collections import deque

def bfs_search(problem):
    """Breadth-first search implementation."""
    
    # Node: (state, path_from_initial, cost)
    initial_node = (problem.initial, [], 0)
    
    if problem.is_goal(problem.initial):
        return []
    
    frontier = deque([initial_node])  # FIFO queue
    explored = set()
    nodes_expanded = 0
    
    print("BREADTH-FIRST SEARCH")
    print("=" * 50)
    
    while frontier:
        print(f"\nFrontier size: {len(frontier)}, Explored: {len(explored)}")
        
        # Remove first node from frontier (FIFO)
        state, path, cost = frontier.popleft()
        nodes_expanded += 1
        
        print(f"Exploring node {nodes_expanded} (depth {len(path)}):")
        problem.display_state(state)
        
        explored.add(state)
        
        # Expand the node - show what actions are available
        actions = problem.get_actions(state)
        print(f"  Available actions: {actions}")
        
        for action in actions:
            child_state = problem.result(state, action)
            print(f"  Applying '{action}' →", end=" ")
            
            if child_state not in explored and child_state not in [n[0] for n in frontier]:
                child_path = path + [action]
                child_cost = cost + 1
                
                if problem.is_goal(child_state):
                    print("GOAL!")
                    print(f"\n{'='*50}")
                    print(f"✓ Goal found! Total nodes expanded: {nodes_expanded}")
                    print(f"\nGoal state reached:")
                    problem.display_state(child_state)
                    print(f"\nSolution path: {child_path}")
                    print(f"Path length: {len(child_path)}")
                    return child_path
                else:
                    print("added to frontier")
                
                frontier.append((child_state, child_path, child_cost))
            else:
                if child_state in explored:
                    print("already explored")
                else:
                    print("already in frontier")
    
    return None  # No solution

initial = (1, 2, 3, 4, 5, 6, 0, 7, 8)
goal = (1, 2, 3, 4, 5, 6, 7, 8, 0)

# Problem requiring 4 moves for more interesting exploration
# initial = (1, 2, 3, 4, 0, 5, 7, 8, 6)  # Blank at position 4 (center)
# goal = (1, 2, 3, 4, 5, 6, 7, 8, 0)      # Standard goal (blank at bottom-right)

problem = EightPuzzle(initial, goal)
solution = bfs_search(problem)
# Out:
# BREADTH-FIRST SEARCH
# ==================================================
#
# Frontier size: 1, Explored: 0
# Exploring node 1 (depth 0):
#   1 2 3
#   4 5 6
#   0 7 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'UP' → added to frontier
#   Applying 'RIGHT' → added to frontier
#
# Frontier size: 2, Explored: 1
# Exploring node 2 (depth 1):
#   1 2 3
#   0 5 6
#   4 7 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'UP' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'RIGHT' → added to frontier
#
# Frontier size: 3, Explored: 2
# Exploring node 3 (depth 1):
#   1 2 3
#   4 5 6
#   7 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'UP' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'RIGHT' → GOAL!
#
# ==================================================
# ✓ Goal found! Total nodes expanded: 3
#
# Goal state reached:
#   1 2 3
#   4 5 6
#   7 8 0
#
# Solution path: ['RIGHT', 'RIGHT']
# Path length: 2

# %%
def dfs_search(problem, max_depth=20):
    """Depth-first search with depth limiting."""
    
    initial_node = (problem.initial, [], 0)
    
    if problem.is_goal(problem.initial):
        return []
    
    frontier = [initial_node]  # LIFO stack (use list as stack)
    explored = set()
    nodes_expanded = 0
    max_frontier_size = 1
    
    print("DEPTH-FIRST SEARCH")
    print("=" * 50)
    
    while frontier:
        max_frontier_size = max(max_frontier_size, len(frontier))
        
        # Remove last node from frontier (LIFO)
        state, path, cost = frontier.pop()
        
        if len(path) > max_depth:
            continue  # Depth limit reached
        
        nodes_expanded += 1
        print(f"\nExploring node {nodes_expanded} (depth {len(path)}):")
        problem.display_state(state)
        
        if problem.is_goal(state):
            print(f"\n{'='*50}")
            print(f"✓ Goal found! Total nodes expanded: {nodes_expanded}")
            print(f"Maximum frontier size: {max_frontier_size}")
            print(f"\nGoal state reached:")
            problem.display_state(state)
            print(f"\nSolution path: {path}")
            print(f"Path length: {len(path)}")
            return path
        
        explored.add(state)
        
        # Show available actions
        actions = problem.get_actions(state)
        print(f"  Available actions: {actions}")
        
        # Add children to frontier (in reverse order for consistent behavior)
        for action in reversed(actions):
            child_state = problem.result(state, action)
            print(f"  Applying '{action}' →", end=" ")
            
            if child_state not in explored and child_state not in [n[0] for n in frontier]:
                child_path = path + [action]
                child_cost = cost + 1
                frontier.append((child_state, child_path, child_cost))
                print("added to frontier")
            else:
                if child_state in explored:
                    print("already explored")
                else:
                    print("already in frontier")
    
    return None

initial = (1, 2, 3, 4, 5, 6, 0, 7, 8)
goal = (1, 2, 3, 4, 5, 6, 7, 8, 0)

# Problem requiring 4 moves for more interesting exploration
# initial = (1, 2, 3, 4, 0, 5, 7, 8, 6)  # Blank at position 4 (center)
# goal = (1, 2, 3, 4, 5, 6, 7, 8, 0)      # Standard goal (blank at bottom-right)

problem = EightPuzzle(initial, goal)
solution = dfs_search(problem)
# Out:
# DEPTH-FIRST SEARCH
# ==================================================
#
# Exploring node 1 (depth 0):
#   1 2 3
#   4 5 6
#   0 7 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 2 (depth 1):
#   1 2 3
#   0 5 6
#   4 7 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 3 (depth 2):
#   0 2 3
#   1 5 6
#   4 7 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 4 (depth 3):
#   2 0 3
#   1 5 6
#   4 7 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 5 (depth 4):
#   2 5 3
#   1 0 6
#   4 7 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6 (depth 5):
#   2 5 3
#   1 7 6
#   4 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 7 (depth 6):
#   2 5 3
#   1 7 6
#   0 4 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 8 (depth 7):
#   2 5 3
#   0 7 6
#   1 4 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 9 (depth 8):
#   0 5 3
#   2 7 6
#   1 4 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 10 (depth 9):
#   5 0 3
#   2 7 6
#   1 4 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 11 (depth 10):
#   5 7 3
#   2 0 6
#   1 4 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 12 (depth 11):
#   5 7 3
#   2 4 6
#   1 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 13 (depth 12):
#   5 7 3
#   2 4 6
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 14 (depth 13):
#   5 7 3
#   0 4 6
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 15 (depth 14):
#   0 7 3
#   5 4 6
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 16 (depth 15):
#   7 0 3
#   5 4 6
#   2 1 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 17 (depth 16):
#   7 4 3
#   5 0 6
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 18 (depth 17):
#   7 4 3
#   5 1 6
#   2 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 19 (depth 18):
#   7 4 3
#   5 1 6
#   0 2 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 20 (depth 19):
#   7 4 3
#   0 1 6
#   5 2 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 21 (depth 20):
#   0 4 3
#   7 1 6
#   5 2 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 22 (depth 20):
#   7 4 3
#   1 0 6
#   5 2 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 23 (depth 18):
#   7 4 3
#   5 1 6
#   2 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 24 (depth 19):
#   7 4 3
#   5 1 0
#   2 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 25 (depth 20):
#   7 4 0
#   5 1 3
#   2 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 26 (depth 20):
#   7 4 3
#   5 0 1
#   2 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 27 (depth 17):
#   7 4 3
#   0 5 6
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 28 (depth 18):
#   0 4 3
#   7 5 6
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 29 (depth 19):
#   4 0 3
#   7 5 6
#   2 1 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 30 (depth 20):
#   4 5 3
#   7 0 6
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 31 (depth 20):
#   4 3 0
#   7 5 6
#   2 1 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 32 (depth 18):
#   7 4 3
#   2 5 6
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 33 (depth 19):
#   7 4 3
#   2 5 6
#   1 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 34 (depth 20):
#   7 4 3
#   2 0 6
#   1 5 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 35 (depth 20):
#   7 4 3
#   2 5 6
#   1 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 36 (depth 17):
#   7 4 3
#   5 6 0
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 37 (depth 18):
#   7 4 0
#   5 6 3
#   2 1 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 38 (depth 19):
#   7 0 4
#   5 6 3
#   2 1 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 39 (depth 20):
#   7 6 4
#   5 0 3
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 40 (depth 20):
#   0 7 4
#   5 6 3
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 41 (depth 18):
#   7 4 3
#   5 6 8
#   2 1 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 42 (depth 19):
#   7 4 3
#   5 6 8
#   2 0 1
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 43 (depth 20):
#   7 4 3
#   5 0 8
#   2 6 1
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 44 (depth 20):
#   7 4 3
#   5 6 8
#   0 2 1
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 45 (depth 16):
#   7 3 0
#   5 4 6
#   2 1 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 46 (depth 17):
#   7 3 6
#   5 4 0
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 47 (depth 18):
#   7 3 6
#   5 4 8
#   2 1 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 48 (depth 19):
#   7 3 6
#   5 4 8
#   2 0 1
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 49 (depth 20):
#   7 3 6
#   5 0 8
#   2 4 1
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 50 (depth 20):
#   7 3 6
#   5 4 8
#   0 2 1
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 51 (depth 18):
#   7 3 6
#   5 0 4
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 52 (depth 19):
#   7 0 6
#   5 3 4
#   2 1 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 53 (depth 20):
#   0 7 6
#   5 3 4
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 54 (depth 20):
#   7 6 0
#   5 3 4
#   2 1 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 55 (depth 19):
#   7 3 6
#   5 1 4
#   2 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 56 (depth 20):
#   7 3 6
#   5 1 4
#   0 2 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 57 (depth 20):
#   7 3 6
#   5 1 4
#   2 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 58 (depth 19):
#   7 3 6
#   0 5 4
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 59 (depth 20):
#   0 3 6
#   7 5 4
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 60 (depth 20):
#   7 3 6
#   2 5 4
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 61 (depth 14):
#   5 7 3
#   4 0 6
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 62 (depth 15):
#   5 0 3
#   4 7 6
#   2 1 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 63 (depth 16):
#   0 5 3
#   4 7 6
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 64 (depth 17):
#   4 5 3
#   0 7 6
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 65 (depth 18):
#   4 5 3
#   2 7 6
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 66 (depth 19):
#   4 5 3
#   2 7 6
#   1 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 67 (depth 20):
#   4 5 3
#   2 0 6
#   1 7 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 68 (depth 20):
#   4 5 3
#   2 7 6
#   1 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 69 (depth 16):
#   5 3 0
#   4 7 6
#   2 1 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 70 (depth 17):
#   5 3 6
#   4 7 0
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 71 (depth 18):
#   5 3 6
#   4 7 8
#   2 1 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 72 (depth 19):
#   5 3 6
#   4 7 8
#   2 0 1
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 73 (depth 20):
#   5 3 6
#   4 0 8
#   2 7 1
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 74 (depth 20):
#   5 3 6
#   4 7 8
#   0 2 1
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 75 (depth 18):
#   5 3 6
#   4 0 7
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 76 (depth 19):
#   5 0 6
#   4 3 7
#   2 1 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 77 (depth 20):
#   0 5 6
#   4 3 7
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 78 (depth 20):
#   5 6 0
#   4 3 7
#   2 1 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 79 (depth 19):
#   5 3 6
#   4 1 7
#   2 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 80 (depth 20):
#   5 3 6
#   4 1 7
#   0 2 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 81 (depth 20):
#   5 3 6
#   4 1 7
#   2 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 82 (depth 19):
#   5 3 6
#   0 4 7
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 83 (depth 20):
#   0 3 6
#   5 4 7
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 84 (depth 20):
#   5 3 6
#   2 4 7
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 85 (depth 15):
#   5 7 3
#   4 1 6
#   2 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 86 (depth 16):
#   5 7 3
#   4 1 6
#   0 2 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 87 (depth 17):
#   5 7 3
#   0 1 6
#   4 2 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 88 (depth 18):
#   0 7 3
#   5 1 6
#   4 2 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 89 (depth 19):
#   7 0 3
#   5 1 6
#   4 2 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 90 (depth 20):
#   7 1 3
#   5 0 6
#   4 2 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 91 (depth 20):
#   7 3 0
#   5 1 6
#   4 2 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 92 (depth 18):
#   5 7 3
#   1 0 6
#   4 2 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 93 (depth 19):
#   5 0 3
#   1 7 6
#   4 2 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 94 (depth 20):
#   0 5 3
#   1 7 6
#   4 2 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 95 (depth 20):
#   5 3 0
#   1 7 6
#   4 2 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 96 (depth 19):
#   5 7 3
#   1 2 6
#   4 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 97 (depth 20):
#   5 7 3
#   1 2 6
#   0 4 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → already in frontier
#
# Exploring node 98 (depth 20):
#   5 7 3
#   1 2 6
#   4 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 99 (depth 19):
#   5 7 3
#   1 6 0
#   4 2 8
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 100 (depth 20):
#   5 7 0
#   1 6 3
#   4 2 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 101 (depth 20):
#   5 7 3
#   1 6 8
#   4 2 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 102 (depth 16):
#   5 7 3
#   4 1 6
#   2 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 103 (depth 17):
#   5 7 3
#   4 1 0
#   2 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 104 (depth 18):
#   5 7 0
#   4 1 3
#   2 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 105 (depth 19):
#   5 0 7
#   4 1 3
#   2 8 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 106 (depth 20):
#   5 1 7
#   4 0 3
#   2 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 107 (depth 20):
#   0 5 7
#   4 1 3
#   2 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 108 (depth 18):
#   5 7 3
#   4 0 1
#   2 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 109 (depth 19):
#   5 0 3
#   4 7 1
#   2 8 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 110 (depth 20):
#   0 5 3
#   4 7 1
#   2 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 111 (depth 20):
#   5 3 0
#   4 7 1
#   2 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 112 (depth 19):
#   5 7 3
#   4 8 1
#   2 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 113 (depth 20):
#   5 7 3
#   4 8 1
#   0 2 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 114 (depth 20):
#   5 7 3
#   4 8 1
#   2 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 115 (depth 19):
#   5 7 3
#   0 4 1
#   2 8 6
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 116 (depth 20):
#   0 7 3
#   5 4 1
#   2 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 117 (depth 20):
#   5 7 3
#   2 4 1
#   0 8 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 118 (depth 15):
#   5 7 3
#   4 6 0
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 119 (depth 16):
#   5 7 0
#   4 6 3
#   2 1 8
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 120 (depth 17):
#   5 0 7
#   4 6 3
#   2 1 8
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 121 (depth 18):
#   5 6 7
#   4 0 3
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 122 (depth 19):
#   5 6 7
#   4 1 3
#   2 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 123 (depth 20):
#   5 6 7
#   4 1 3
#   0 2 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 124 (depth 20):
#   5 6 7
#   4 1 3
#   2 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 125 (depth 19):
#   5 6 7
#   0 4 3
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 126 (depth 20):
#   0 6 7
#   5 4 3
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 127 (depth 20):
#   5 6 7
#   2 4 3
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 128 (depth 19):
#   5 6 7
#   4 3 0
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 129 (depth 20):
#   5 6 7
#   4 3 8
#   2 1 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 130 (depth 18):
#   0 5 7
#   4 6 3
#   2 1 8
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 131 (depth 19):
#   4 5 7
#   0 6 3
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 132 (depth 20):
#   4 5 7
#   2 6 3
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 133 (depth 20):
#   4 5 7
#   6 0 3
#   2 1 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 134 (depth 16):
#   5 7 3
#   4 6 8
#   2 1 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 135 (depth 17):
#   5 7 3
#   4 6 8
#   2 0 1
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 136 (depth 18):
#   5 7 3
#   4 0 8
#   2 6 1
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 137 (depth 19):
#   5 0 3
#   4 7 8
#   2 6 1
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 138 (depth 20):
#   0 5 3
#   4 7 8
#   2 6 1
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 139 (depth 20):
#   5 3 0
#   4 7 8
#   2 6 1
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 140 (depth 19):
#   5 7 3
#   0 4 8
#   2 6 1
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 141 (depth 20):
#   0 7 3
#   5 4 8
#   2 6 1
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 142 (depth 20):
#   5 7 3
#   2 4 8
#   0 6 1
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 143 (depth 19):
#   5 7 3
#   4 8 0
#   2 6 1
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 144 (depth 20):
#   5 7 0
#   4 8 3
#   2 6 1
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 145 (depth 18):
#   5 7 3
#   4 6 8
#   0 2 1
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 146 (depth 19):
#   5 7 3
#   0 6 8
#   4 2 1
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 147 (depth 20):
#   0 7 3
#   5 6 8
#   4 2 1
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 148 (depth 20):
#   5 7 3
#   6 0 8
#   4 2 1
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 149 (depth 12):
#   5 7 3
#   2 4 6
#   1 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 150 (depth 13):
#   5 7 3
#   2 4 0
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 151 (depth 14):
#   5 7 0
#   2 4 3
#   1 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 152 (depth 15):
#   5 0 7
#   2 4 3
#   1 8 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 153 (depth 16):
#   5 4 7
#   2 0 3
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 154 (depth 17):
#   5 4 7
#   2 8 3
#   1 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 155 (depth 18):
#   5 4 7
#   2 8 3
#   0 1 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 156 (depth 19):
#   5 4 7
#   0 8 3
#   2 1 6
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 157 (depth 20):
#   0 4 7
#   5 8 3
#   2 1 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 158 (depth 20):
#   5 4 7
#   8 0 3
#   2 1 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 159 (depth 18):
#   5 4 7
#   2 8 3
#   1 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 160 (depth 19):
#   5 4 7
#   2 8 0
#   1 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 161 (depth 20):
#   5 4 0
#   2 8 7
#   1 6 3
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 162 (depth 20):
#   5 4 7
#   2 0 8
#   1 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 163 (depth 17):
#   5 4 7
#   0 2 3
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 164 (depth 18):
#   0 4 7
#   5 2 3
#   1 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 165 (depth 19):
#   4 0 7
#   5 2 3
#   1 8 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 166 (depth 20):
#   4 2 7
#   5 0 3
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 167 (depth 20):
#   4 7 0
#   5 2 3
#   1 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 168 (depth 18):
#   5 4 7
#   1 2 3
#   0 8 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 169 (depth 19):
#   5 4 7
#   1 2 3
#   8 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 170 (depth 20):
#   5 4 7
#   1 0 3
#   8 2 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 171 (depth 20):
#   5 4 7
#   1 2 3
#   8 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 172 (depth 17):
#   5 4 7
#   2 3 0
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 173 (depth 18):
#   5 4 0
#   2 3 7
#   1 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 174 (depth 19):
#   5 0 4
#   2 3 7
#   1 8 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 175 (depth 20):
#   5 3 4
#   2 0 7
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 176 (depth 20):
#   0 5 4
#   2 3 7
#   1 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 177 (depth 18):
#   5 4 7
#   2 3 6
#   1 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 178 (depth 19):
#   5 4 7
#   2 3 6
#   1 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 179 (depth 20):
#   5 4 7
#   2 0 6
#   1 3 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 180 (depth 20):
#   5 4 7
#   2 3 6
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 181 (depth 16):
#   0 5 7
#   2 4 3
#   1 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 182 (depth 17):
#   2 5 7
#   0 4 3
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 183 (depth 18):
#   2 5 7
#   1 4 3
#   0 8 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 184 (depth 19):
#   2 5 7
#   1 4 3
#   8 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 185 (depth 20):
#   2 5 7
#   1 0 3
#   8 4 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 186 (depth 20):
#   2 5 7
#   1 4 3
#   8 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 187 (depth 18):
#   2 5 7
#   4 0 3
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 188 (depth 19):
#   2 0 7
#   4 5 3
#   1 8 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 189 (depth 20):
#   0 2 7
#   4 5 3
#   1 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 190 (depth 20):
#   2 7 0
#   4 5 3
#   1 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 191 (depth 19):
#   2 5 7
#   4 8 3
#   1 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 192 (depth 20):
#   2 5 7
#   4 8 3
#   0 1 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 193 (depth 20):
#   2 5 7
#   4 8 3
#   1 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 194 (depth 19):
#   2 5 7
#   4 3 0
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 195 (depth 20):
#   2 5 0
#   4 3 7
#   1 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 196 (depth 20):
#   2 5 7
#   4 3 6
#   1 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 197 (depth 14):
#   5 7 3
#   2 0 4
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 198 (depth 15):
#   5 0 3
#   2 7 4
#   1 8 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 199 (depth 16):
#   0 5 3
#   2 7 4
#   1 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 200 (depth 17):
#   2 5 3
#   0 7 4
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 201 (depth 18):
#   2 5 3
#   1 7 4
#   0 8 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 202 (depth 19):
#   2 5 3
#   1 7 4
#   8 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 203 (depth 20):
#   2 5 3
#   1 0 4
#   8 7 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 204 (depth 20):
#   2 5 3
#   1 7 4
#   8 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 205 (depth 18):
#   2 5 3
#   7 0 4
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 206 (depth 19):
#   2 0 3
#   7 5 4
#   1 8 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 207 (depth 20):
#   0 2 3
#   7 5 4
#   1 8 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 208 (depth 20):
#   2 3 0
#   7 5 4
#   1 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 209 (depth 19):
#   2 5 3
#   7 8 4
#   1 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 210 (depth 20):
#   2 5 3
#   7 8 4
#   0 1 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 211 (depth 20):
#   2 5 3
#   7 8 4
#   1 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 212 (depth 19):
#   2 5 3
#   7 4 0
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 213 (depth 20):
#   2 5 0
#   7 4 3
#   1 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 214 (depth 20):
#   2 5 3
#   7 4 6
#   1 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 215 (depth 16):
#   5 3 0
#   2 7 4
#   1 8 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 216 (depth 17):
#   5 3 4
#   2 7 0
#   1 8 6
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 217 (depth 18):
#   5 3 4
#   2 7 6
#   1 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 218 (depth 19):
#   5 3 4
#   2 7 6
#   1 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 219 (depth 20):
#   5 3 4
#   2 0 6
#   1 7 8
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 220 (depth 20):
#   5 3 4
#   2 7 6
#   0 1 8
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 221 (depth 15):
#   5 7 3
#   2 8 4
#   1 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 222 (depth 16):
#   5 7 3
#   2 8 4
#   0 1 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 223 (depth 17):
#   5 7 3
#   0 8 4
#   2 1 6
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 224 (depth 18):
#   0 7 3
#   5 8 4
#   2 1 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 225 (depth 19):
#   7 0 3
#   5 8 4
#   2 1 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 226 (depth 20):
#   7 8 3
#   5 0 4
#   2 1 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 227 (depth 20):
#   7 3 0
#   5 8 4
#   2 1 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 228 (depth 18):
#   5 7 3
#   8 0 4
#   2 1 6
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 229 (depth 19):
#   5 0 3
#   8 7 4
#   2 1 6
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 230 (depth 20):
#   0 5 3
#   8 7 4
#   2 1 6
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 231 (depth 20):
#   5 3 0
#   8 7 4
#   2 1 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 232 (depth 19):
#   5 7 3
#   8 1 4
#   2 0 6
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 233 (depth 20):
#   5 7 3
#   8 1 4
#   0 2 6
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 234 (depth 20):
#   5 7 3
#   8 1 4
#   2 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 235 (depth 19):
#   5 7 3
#   8 4 0
#   2 1 6
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 236 (depth 20):
#   5 7 0
#   8 4 3
#   2 1 6
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 237 (depth 20):
#   5 7 3
#   8 4 6
#   2 1 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 238 (depth 16):
#   5 7 3
#   2 8 4
#   1 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 239 (depth 17):
#   5 7 3
#   2 8 0
#   1 6 4
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 240 (depth 18):
#   5 7 0
#   2 8 3
#   1 6 4
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 241 (depth 19):
#   5 0 7
#   2 8 3
#   1 6 4
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 242 (depth 20):
#   5 8 7
#   2 0 3
#   1 6 4
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# ...
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6399 (depth 18):
#   0 1 2
#   5 4 6
#   8 3 7
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6400 (depth 19):
#   1 0 2
#   5 4 6
#   8 3 7
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6401 (depth 20):
#   1 4 2
#   5 0 6
#   8 3 7
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6402 (depth 20):
#   1 2 0
#   5 4 6
#   8 3 7
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6403 (depth 18):
#   5 1 2
#   8 4 6
#   0 3 7
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6404 (depth 19):
#   5 1 2
#   8 4 6
#   3 0 7
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6405 (depth 20):
#   5 1 2
#   8 0 6
#   3 4 7
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6406 (depth 20):
#   5 1 2
#   8 4 6
#   3 7 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6407 (depth 17):
#   5 1 2
#   4 6 0
#   8 3 7
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6408 (depth 18):
#   5 1 0
#   4 6 2
#   8 3 7
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6409 (depth 19):
#   5 0 1
#   4 6 2
#   8 3 7
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6410 (depth 20):
#   5 6 1
#   4 0 2
#   8 3 7
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6411 (depth 20):
#   0 5 1
#   4 6 2
#   8 3 7
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6412 (depth 18):
#   5 1 2
#   4 6 7
#   8 3 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6413 (depth 19):
#   5 1 2
#   4 6 7
#   8 0 3
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6414 (depth 20):
#   5 1 2
#   4 0 7
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6415 (depth 20):
#   5 1 2
#   4 6 7
#   0 8 3
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6416 (depth 16):
#   5 1 2
#   4 3 6
#   0 8 7
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6417 (depth 17):
#   5 1 2
#   0 3 6
#   4 8 7
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6418 (depth 18):
#   0 1 2
#   5 3 6
#   4 8 7
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6419 (depth 19):
#   1 0 2
#   5 3 6
#   4 8 7
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6420 (depth 20):
#   1 3 2
#   5 0 6
#   4 8 7
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6421 (depth 20):
#   1 2 0
#   5 3 6
#   4 8 7
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6422 (depth 18):
#   5 1 2
#   3 0 6
#   4 8 7
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6423 (depth 19):
#   5 0 2
#   3 1 6
#   4 8 7
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6424 (depth 20):
#   0 5 2
#   3 1 6
#   4 8 7
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6425 (depth 20):
#   5 2 0
#   3 1 6
#   4 8 7
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6426 (depth 19):
#   5 1 2
#   3 8 6
#   4 0 7
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6427 (depth 20):
#   5 1 2
#   3 8 6
#   0 4 7
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6428 (depth 20):
#   5 1 2
#   3 8 6
#   4 7 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6429 (depth 19):
#   5 1 2
#   3 6 0
#   4 8 7
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6430 (depth 20):
#   5 1 0
#   3 6 2
#   4 8 7
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6431 (depth 20):
#   5 1 2
#   3 6 7
#   4 8 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6432 (depth 12):
#   5 1 2
#   4 7 3
#   8 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6433 (depth 13):
#   5 1 2
#   4 7 0
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6434 (depth 14):
#   5 1 0
#   4 7 2
#   8 6 3
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6435 (depth 15):
#   5 0 1
#   4 7 2
#   8 6 3
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6436 (depth 16):
#   5 7 1
#   4 0 2
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6437 (depth 17):
#   5 7 1
#   4 6 2
#   8 0 3
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6438 (depth 18):
#   5 7 1
#   4 6 2
#   0 8 3
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6439 (depth 19):
#   5 7 1
#   0 6 2
#   4 8 3
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6440 (depth 20):
#   0 7 1
#   5 6 2
#   4 8 3
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6441 (depth 20):
#   5 7 1
#   6 0 2
#   4 8 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6442 (depth 18):
#   5 7 1
#   4 6 2
#   8 3 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6443 (depth 19):
#   5 7 1
#   4 6 0
#   8 3 2
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6444 (depth 20):
#   5 7 0
#   4 6 1
#   8 3 2
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6445 (depth 20):
#   5 7 1
#   4 0 6
#   8 3 2
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6446 (depth 17):
#   5 7 1
#   0 4 2
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6447 (depth 18):
#   0 7 1
#   5 4 2
#   8 6 3
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6448 (depth 19):
#   7 0 1
#   5 4 2
#   8 6 3
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6449 (depth 20):
#   7 4 1
#   5 0 2
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6450 (depth 20):
#   7 1 0
#   5 4 2
#   8 6 3
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6451 (depth 18):
#   5 7 1
#   8 4 2
#   0 6 3
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6452 (depth 19):
#   5 7 1
#   8 4 2
#   6 0 3
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6453 (depth 20):
#   5 7 1
#   8 0 2
#   6 4 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6454 (depth 20):
#   5 7 1
#   8 4 2
#   6 3 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6455 (depth 17):
#   5 7 1
#   4 2 0
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6456 (depth 18):
#   5 7 0
#   4 2 1
#   8 6 3
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6457 (depth 19):
#   5 0 7
#   4 2 1
#   8 6 3
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6458 (depth 20):
#   5 2 7
#   4 0 1
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6459 (depth 20):
#   0 5 7
#   4 2 1
#   8 6 3
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6460 (depth 16):
#   0 5 1
#   4 7 2
#   8 6 3
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6461 (depth 17):
#   4 5 1
#   0 7 2
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6462 (depth 18):
#   4 5 1
#   8 7 2
#   0 6 3
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6463 (depth 19):
#   4 5 1
#   8 7 2
#   6 0 3
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6464 (depth 20):
#   4 5 1
#   8 0 2
#   6 7 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6465 (depth 20):
#   4 5 1
#   8 7 2
#   6 3 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6466 (depth 18):
#   4 5 1
#   7 0 2
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6467 (depth 19):
#   4 0 1
#   7 5 2
#   8 6 3
#   Available actions: ['DOWN', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6468 (depth 20):
#   0 4 1
#   7 5 2
#   8 6 3
#   Available actions: ['DOWN', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6469 (depth 20):
#   4 1 0
#   7 5 2
#   8 6 3
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#
# Exploring node 6470 (depth 19):
#   4 5 1
#   7 6 2
#   8 0 3
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6471 (depth 20):
#   4 5 1
#   7 6 2
#   0 8 3
#   Available actions: ['UP', 'RIGHT']
#   Applying 'RIGHT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6472 (depth 20):
#   4 5 1
#   7 6 2
#   8 3 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'UP' → added to frontier
#
# Exploring node 6473 (depth 19):
#   4 5 1
#   7 2 0
#   8 6 3
#   Available actions: ['UP', 'DOWN', 'LEFT']
#   Applying 'LEFT' → already explored
#   Applying 'DOWN' → added to frontier
#   Applying 'UP' → added to frontier
#
# Exploring node 6474 (depth 20):
#   4 5 0
#   7 2 1
#   8 6 3
#   Available actions: ['DOWN', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'DOWN' → already explored
#
# Exploring node 6475 (depth 20):
#   4 5 1
#   7 2 3
#   8 6 0
#   Available actions: ['UP', 'LEFT']
#   Applying 'LEFT' → added to frontier
#   Applying 'UP' → already explored
#
# Exploring node 6476 (depth 1):
#   1 2 3
#   4 5 6
#   7 0 8
#   Available actions: ['UP', 'LEFT', 'RIGHT']
#   Applying 'RIGHT' → added to frontier
#   Applying 'LEFT' → already explored
#   Applying 'UP' → already explored
#
# Exploring node 6477 (depth 2):
#   1 2 3
#   4 5 6
#   7 8 0
#
# ==================================================
# ✓ Goal found! Total nodes expanded: 6477
# Maximum frontier size: 19
#
# Goal state reached:
#   1 2 3
#   4 5 6
#   7 8 0
#
# Solution path: ['RIGHT', 'RIGHT']
# Path length: 2
